# %% [markdown]
# # McGreasy Diet Problem
#
# A simple diet model

# %%
import sys
import gamspy as gp

# %%
options = gp.Options(equation_listing_limit=100)
m = gp.Container(load_from='mcgreasy.gdx',options=options)
# extract the sets and parameters for the gdx file
food, nutr, a, min_nutr, cost = m.getSymbols(["food","nutr","a","min_nutr","cost"])
for name, symbol in m:
    print(f"Name: {name}, records: {symbol.records}")
# Out:
# Name: food, records:   uni element_text
# 0  QP
# 1  MD
# 2  BM
# 3  FF
# 4  MC
# 5  FR
# 6  SM
# 7  1M
# 8  OJ
# Name: nutr, records:     uni element_text
# 0  Prot
# 1  VitA
# 2  VitC
# 3  Calc
# 4  Iron
# 5  Cals
# 6  Carb
# Name: a, records:     nutr food  value
# 0   Prot   QP   28.0
# 1   Prot   MD   24.0
# 2   Prot   BM   25.0
# 3   Prot   FF   14.0
# 4   Prot   MC   31.0
# 5   Prot   FR    3.0
# 6   Prot   SM   15.0
# 7   Prot   1M    9.0
# 8   Prot   OJ    1.0
# 9   VitA   QP   15.0
# 10  VitA   MD   15.0
# 11  VitA   BM    6.0
# 12  VitA   FF    2.0
# 13  VitA   MC    8.0
# 14  VitA   SM    4.0
# 15  VitA   1M   10.0
# 16  VitA   OJ    2.0
# 17  VitC   QP    6.0
# 18  VitC   MD   10.0
# 19  VitC   BM    2.0
# 20  VitC   MC   15.0
# 21  VitC   FR   15.0
# 22  VitC   1M    4.0
# 23  VitC   OJ  120.0
# 24  Calc   QP   30.0
# 25  Calc   MD   20.0
# 26  Calc   BM   25.0
# 27  Calc   FF   15.0
# 28  Calc   MC   15.0
# 29  Calc   SM   20.0
# 30  Calc   1M   30.0
# 31  Calc   OJ    2.0
# 32  Iron   QP   20.0
# 33  Iron   MD   20.0
# 34  Iron   BM   20.0
# 35  Iron   FF   10.0
# 36  Iron   MC    8.0
# 37  Iron   FR    2.0
# 38  Iron   SM   15.0
# 39  Iron   OJ    2.0
# 40  Cals   QP  510.0
# 41  Cals   MD  370.0
# 42  Cals   BM  500.0
# 43  Cals   FF  370.0
# 44  Cals   MC  400.0
# 45  Cals   FR  220.0
# 46  Cals   SM  345.0
# 47  Cals   1M  110.0
# 48  Cals   OJ   80.0
# 49  Carb   QP   34.0
# 50  Carb   MD   33.0
# 51  Carb   BM   42.0
# 52  Carb   FF   38.0
# 53  Carb   MC   42.0
# 54  Carb   FR   26.0
# 55  Carb   SM   27.0
# 56  Carb   1M   12.0
# 57  Carb   OJ   20.0
# Name: min_nutr, records:    nutr   value
# 0  Prot    55.0
# 1  VitA   100.0
# 2  VitC   100.0
# 3  Calc   100.0
# 4  Iron   100.0
# 5  Cals  2000.0
# 6  Carb   350.0
# Name: cost, records:   food  value
# 0   QP   1.84
# 1   MD   2.19
# 2   BM   1.84
# 3   FF   1.44
# 4   MC   2.29
# 5   FR   0.77
# 6   SM   1.29
# 7   1M   0.60
# 8   OJ   0.72
# Name: total_cost, records:        level  marginal  lower  upper  scale
# 0  14.855738       0.0   -inf    inf    1.0
# Name: x, records:   food     level  marginal  lower  upper  scale
# 0   QP  4.385246  0.000000    0.0    inf    1.0
# 1   MD  0.000000  0.377705    0.0    inf    1.0
# 2   BM  0.000000  0.019148    0.0    inf    1.0
# 3   FF  0.000000  0.085344    0.0    inf    1.0
# 4   MC  0.000000  0.713672    0.0    inf    1.0
# 5   FR  6.147541  0.000000    0.0    inf    1.0
# 6   SM  0.000000  0.062410    0.0    inf    1.0
# 7   1M  3.422131  0.000000    0.0    inf    1.0
# 8   OJ  0.000000  0.062721    0.0    inf    1.0
# Name: cost_eqn, records:    level  marginal  lower  upper  scale
# 0   -0.0       1.0   -0.0   -0.0    1.0
# Name: min_nutr_eqn, records:    nutr        level  marginal   lower  upper  scale
# 0  Prot   172.028689  0.000000    55.0    inf    1.0
# 1  VitA   100.000000  0.026754   100.0    inf    1.0
# 2  VitC   132.213115  0.000000   100.0    inf    1.0
# 3  Calc   234.221311  0.000000   100.0    inf    1.0
# 4  Iron   100.000000  0.024836   100.0    inf    1.0
# 5  Cals  3965.368852  0.000000  2000.0    inf    1.0
# 6  Carb   350.000000  0.027705   350.0    inf    1.0

# %%
x = gp.Variable(m,'x','positive',domain=[food],description="Number of each type of food to eat")

min_nutr_eqn = gp.Equation(m,'min_nutr_eqn',domain=[nutr],description="Minimum Daily Requirement")
min_nutr_eqn[nutr]= (
    gp.Sum(food, a[nutr,food]*x[food]) >= min_nutr[nutr] )

diet = gp.Model(m,'diet',
                   equations = [min_nutr_eqn],
                   problem = "LP",
                   sense = "MIN",
                   objective = gp.Sum(food, cost[food]*x[food]),
                  )

diet.solve()
# Out:
#   Solver Status   Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalGlobal  14.855738                 8                10
#
#   Model Type Solver  Solver Time
# 0         LP  CPLEX          0.0

# %%
# view all the foods that were eaten
xvals = x.records[['food','level']].set_index('food').copy()
display(xvals[xvals['level']!=0])
# Out:
#          level
# food
# QP    4.385246
# FR    6.147541
# 1M    3.422131

# %% [markdown]
# ## Change the problem
#
# What if this person really liked beef?

# %%
# new set of food with beef
beef = gp.Set(m,'beef',domain=[food],records=['QP', 'MD', 'BM'])

# we want to maxsize the beef intake
beef1 = gp.Model(m,'beef1',
                   equations = [min_nutr_eqn],
                   problem = "LP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

beef1.solve(solver="highs")
# notice how the model is unbounded, none of teh vars have upper lims
# Out:
#   Solver Status Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal    Unbounded  10.606061                 8                10
#
#   Model Type Solver  Solver Time
# 0         LP  HIGHS        0.016

# %%
# these are the nutrients we'll set limits on
bad_nutr = gp.Set(m,'bad_nutr',domain=[nutr],records=['Cals', 'Carb'])
max_nutr = gp.Parameter(m,'max_nutr',domain=[nutr])
max_nutr[bad_nutr] = 2 * min_nutr[bad_nutr]

max_nutr_req = gp.Equation(m,'max_nutr_req',domain=[nutr])
max_nutr_req[bad_nutr]=(
    gp.Sum(food,a[bad_nutr,food]*x[food]) <= max_nutr[bad_nutr] )

beef1 = gp.Model(m,'beef1',
                   equations = [min_nutr_eqn,max_nutr_req],
                   problem = "LP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

beef1.solve()
# Out:
#   Solver Status   Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalGlobal  10.810811                10                10
#
#   Model Type Solver  Solver Time
# 0         LP  CPLEX        0.015

# %%
xvals = x.records[['food','level']].set_index('food').copy()
display(xvals[xvals['level']!=0])
# Out:
#           level
# food
# MD    10.810811

# %%
# deactivating the calorie constraint
bad_nutr['Cals'] = False
beef1.solve()
# Out:
#   Solver Status   Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalGlobal  21.212121                 9                10
#
#   Model Type Solver  Solver Time
# 0         LP  CPLEX          0.0

# %%
bad_nutr['Cals'] = True
options.equation_listing_limit=100

# want to create a more 'normal diet'
sandwich_eqn = gp.Equation(m,'sandwich_eqn',description="Only 3 sandwiches per day")
sandwich_eqn[:]= x["QP"] + x["MD"] + x["BM"] + x["FF"] + x["MC"] + x["SM"] <= 3

drinking_eqn = gp.Equation(m,'drinking_eqn',description="Only 3 drinks per day")
drinking_eqn[:]= x["OJ"] + x["1M"] <= 3

norm = gp.Model(m,'norm',
                   equations = [min_nutr_eqn, max_nutr_req, sandwich_eqn, drinking_eqn],
                   problem = "LP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

# Limit french fries too
x.up['FR'] = 2

norm.solve()
# Out:
#   Solver Status      Model Status  Objective  Num of Equations  \
# 0        Normal  InfeasibleGlobal     -182.0                12
#
#    Num of Variables Model Type Solver  Solver Time
# 0                10         LP  CPLEX          0.0

# %%
# we are a little too strict with the constraints leading to "Infeasibility"

# using a slack variable, can be negative if problem calls for it
s = gp.Variable(m,'s','free',description="Surplus variable for drinking_eqn")
drinking_eqn[:]= x["OJ"] + x["1M"] <= 3 + s

mindrink = gp.Model(m,'mindrink',
                   equations = [min_nutr_eqn, max_nutr_req, sandwich_eqn, drinking_eqn],
                   problem = "LP",
                   sense = "MIN",
                   objective = s
                  )

s.lo[:] = 0

mindrink.solve()
# Out:
#   Solver Status   Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalGlobal       16.9                11                10
#
#   Model Type Solver  Solver Time
# 0         LP  CPLEX          0.0

# %%
xvals = x.records[['food','level']].set_index('food').copy()
display(xvals[xvals['level']!=0])
# that's a crazy amount of juice!
# Out:
#       level
# food
# QP      3.0
# FR      2.0
# 1M      1.9
# OJ     18.0

# %% [markdown]
# ### Going to do some analysis on specific vitamins

# %%
jtlvitc = gp.Parameter(m,'jtlvitc')
jtlvitc[:] = gp.Sum(food, a["VitC",food] * x.l[food])
display(jtlvitc.records,jtlvitc.toValue())
# Out:
#     value
# 0  2215.6
# np.float64(2215.6)

# %%
# hold the amount of extra drink that we just found
options.hold_fixed_variables = False
s.fx[:] = s.l

# Note that norm model will be regenerated with new drinking_eqn
norm.solve()
display(s.records,s.toValue(),x.records)
# Out:
#    level  marginal  lower  upper  scale
# 0   16.9      -0.0   16.9   16.9    1.0
# np.float64(16.9)
#   food  level  marginal  lower  upper  scale
# 0   QP    3.0       0.0    0.0    inf    1.0
# 1   MD    0.0      -0.0    0.0    inf    1.0
# 2   BM    0.0      -0.0    0.0    inf    1.0
# 3   FF    0.0      -1.0    0.0    inf    1.0
# 4   MC    0.0      -1.0    0.0    inf    1.0
# 5   FR    2.0      -0.0    0.0    2.0    1.0
# 6   SM    0.0      -1.0    0.0    inf    1.0
# 7   1M    1.9       0.0    0.0    inf    1.0
# 8   OJ   18.0       0.0    0.0    inf    1.0

# %% [markdown]
# ## Now we're going to be dealing with proportional constraints

# %%
cals_eaten = gp.Variable(m,"cals_eaten","positive",description="Number of calories ingested")
cals_eaten.up[:] = 10000

cals_eaten_eqn = gp.Equation(m,'cals_eaten_eqn')
cals_eaten_eqn[:]= cals_eaten == gp.Sum(food,a["Cals",food] * x[food])

vitc_eaten = gp.Variable(m,"vitc_eaten","positive",description="Amount of vitamin C I eat")
vita_eaten = gp.Variable(m,"vita_eaten","positive",description="Amount of vitamin A I eat")

vitc_eaten_eqn = gp.Equation(m,'vitc_eaten_eqn')
vitc_eaten_eqn[:]= vitc_eaten == gp.Sum(food,a["VitC",food] * x[food])

vita_eaten_eqn = gp.Equation(m,'vita_eaten_eqn')
vita_eaten_eqn[:]= vita_eaten == gp.Sum(food,a["VitA",food] * x[food])

limit_vitc_ratio_eqn = gp.Equation(m,'limit_vitc_ratio_eqn')
limit_vitc_ratio_eqn[:]= cals_eaten / vitc_eaten <= 40 

limit_vita_ratio_eqn = gp.Equation(m,'limit_vita_ratio_eqn')
limit_vita_ratio_eqn[:]= cals_eaten / vita_eaten <= 40 

ratiomodel = gp.Model(m,'ratiomodel',
                   equations = [min_nutr_eqn,cals_eaten_eqn,vitc_eaten_eqn,vita_eaten_eqn,limit_vitc_ratio_eqn,limit_vita_ratio_eqn],
                   problem = "LP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

ratiomodel.solve()
# this isn't solvable because it's non linear! (division is not good in linear programming)
# Out:
# ---------------------------------------------------------------------------
# GamspyException                           Traceback (most recent call last)
# Cell In[19], line 29
#      20 limit_vita_ratio_eqn[:]= cals_eaten / vita_eaten <= 40
#      22 ratiomodel = gp.Model(m,'ratiomodel',
#      23                    equations = [min_nutr_eqn,cals_eaten_eqn,vitc_eaten_eqn,vita_eaten_eqn,limit_vitc_ratio_eqn,limit_vita_ratio_eqn],
#      24                    problem = "LP",
#      25                    sense = "MAX",
#      26                    objective = gp.Sum(beef,x[beef])
#      27                   )
# ---> 29 ratiomodel.solve()
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_model.py:1334, in Model.solve(self, solver, options, solver_options, model_instance_options, freeze_options, output, backend, client, load_symbols)
#    1315 options._set_solver_options(
#    1316     container=self.container,
#    1317     solver=solver,
#    1318     problem=self.problem,
#    1319     solver_options=solver_options,
#    1320 )
#    1322 runner = backend_factory(
#    1323     self.container,
#    1324     options,
#    (...)
#    1331     load_symbols,
#    1332 )
# -> 1334 summary = runner.run(relaxed_domain_mapping=False, gams_to_gamspy=True)
#    1336 if IS_MIRO_INIT:
#    1337     miro._write_default_gdx_miro(self.container)
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_backend\local.py:74, in Local.run(self, relaxed_domain_mapping, gams_to_gamspy)
#      71 gams_string = self.preprocess()
#      73 # Run the model
# ---> 74 self.execute_gams(gams_string, gams_to_gamspy)
#      76 # Synchronize GAMSPy with checkpoint and return a summary
#      77 summary = self.postprocess(relaxed_domain_mapping, gams_to_gamspy)
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_backend\local.py:106, in Local.execute_gams(self, gams_string, gams_to_gamspy)
#      99     message = _customize_exception(
#     100         self.options,
#     101         self.job_name,
#     102         exception.return_code,
#     103     )
#     105     exception.args = (exception.message + message,)
# --> 106     raise exception
#     107 finally:
#     108     self.container._unsaved_statements = []
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_backend\local.py:92, in Local.execute_gams(self, gams_string, gams_to_gamspy)
#      89 self.options._export(self.pf_file, self.output)
#      91 try:
# ---> 92     self.container._send_job(self.job_name, self.pf_file, self.output)
#      94     if not self.is_async() and self.model:
#      95         self.model._update_model_attributes()
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_container.py:467, in Container._send_job(self, job_name, pf_file, output)
#     465     # Receive response
#     466     response = self._socket.recv(256)
# --> 467     check_response(response, job_name)
#     468 except ConnectionError as e:
#     469     raise FatalError(
#     470         f"There was an error while communicating with GAMS server: {e}",
#     471     ) from e
#
# File c:\Users\plang\anaconda3\envs\gamspy_env\lib\site-packages\gamspy\_container.py:230, in check_response(response, job_name)
#     227 except IndexError:  # pragma: no cover
#     228     info = ""
# --> 230 raise GamspyException(
#     231     f"Return code {return_code}. {info} Check {job_name + '.lst'} for more information.",
#     232     return_code,
#     233 )
#
# GamspyException: Return code 2. There was a compilation error. Check C:\Users\plang\AppData\Local\Temp\tmpi11ulbcz\_vNoO48Z2THucwO1qXav3kA.lst for more information.
#
# =============
# Error Summary
# =============
# 1098  Parameter autogenerated_domUsd_mTvYeQEpCR22Qg_WevqOlXw / /;
# ****          $55,256
# **** LINE      8 INPUT       C:\Users\plang\AppData\Local\Temp\tmpi11ulbcz\_vNoO48Z2THucwO1qXav3kA.gms
# ****  55  Endogenous operands for / not allowed in linear models
# **** 256  Error(s) in analyzing solve statement.
# **** The following LP errors were detected in model ratiomodel:
# ****  55 equation limit_vitc_ratio_eqn.. VAR operands for /
# ****  55 equation limit_vita_ratio_eqn.. VAR operands for /
#
# **** 2 ERROR(S)   0 WARNING(S)
#
#
# COMPILATION TIME     =        0.016 SECONDS      4 MB  50.4.1 84b10359 WEX-WEI
#
#
# USER: Academic User                                  G250906+0003Ac-GEN
#       rinkam@wisc.edu                                         GPA107788
#       License for teaching and research at degree granting institutions
#
#
# **** FILE SUMMARY
#
# Input      C:\Users\plang\AppData\Local\Temp\tmpi11ulbcz\_vNoO48Z2THucwO1qXav3kA.gms
# Output     C:\Users\plang\AppData\Local\Temp\tmpi11ulbcz\_vNoO48Z2THucwO1qXav3kA.lst
#
# **** USER ERROR(S) ENCOUNTERED

# %%
# switch to non-linear solver, but also fix bounds to avoid dividing by 0
vitc_eaten.l[:] = 1.0 
vita_eaten.l[:] = 1.0

ratiomodel = gp.Model(m,'ratiomodel',
                   equations = [min_nutr_eqn,cals_eaten_eqn,vitc_eaten_eqn,vita_eaten_eqn,limit_vitc_ratio_eqn,limit_vita_ratio_eqn],
                   problem = "NLP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

ratiomodel.solve()
# Out:
#   Solver Status  Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalLocal  27.027027                13                13
#
#   Model Type  Solver  Solver Time
# 0        NLP  IPOPTH        0.026

# %%
# keeping the solution linear 

# just do some simple algebra
linear_limit_vitc_ratio_eqn = gp.Equation(m,'linear_limit_vitc_ratio_eqn')
linear_limit_vitc_ratio_eqn[:]= cals_eaten <= 40 * vitc_eaten

linear_limit_vita_ratio_eqn = gp.Equation(m,'linear_limit_vita_ratio_eqn')
linear_limit_vita_ratio_eqn[:]= cals_eaten <= 40 * vita_eaten  

linear_ratiomodel = gp.Model(m,'ratiomodel',
                   equations = [min_nutr_eqn,cals_eaten_eqn,vitc_eaten_eqn,vita_eaten_eqn,linear_limit_vitc_ratio_eqn,linear_limit_vita_ratio_eqn],
                   problem = "LP",
                   sense = "MAX",
                   objective = gp.Sum(beef,x[beef])
                  )

linear_ratiomodel.solve()
# got the same exact answer
# Out:
#   Solver Status   Model Status  Objective  Num of Equations  Num of Variables  \
# 0        Normal  OptimalGlobal  27.027027                13                13
#
#   Model Type Solver  Solver Time
# 0         LP  CPLEX          0.0

# %%
xvals = x.records[['food','level']].set_index('food').copy()
display(xvals[xvals['level']!=0])
# Out:
#           level
# food
# MD    27.027027
